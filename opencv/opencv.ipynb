# %% [markdown]
# # Getting Familiar with OpenCV

# %% [markdown]
# Photo Credit: https://readthecloud.co/talk-7/

# %%
# !pip install opencv-python imutils
# Out:
# Requirement already satisfied: opencv-python in /Users/zkan/anaconda3/lib/python3.6/site-packages (3.4.3.18)
# Collecting imutils
# Requirement already satisfied: numpy>=1.11.3 in /Users/zkan/anaconda3/lib/python3.6/site-packages (from opencv-python) (1.14.3)
# distributed 1.21.8 requires msgpack, which is not installed.
# Installing collected packages: imutils
# Successfully installed imutils-0.5.1
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading and Showing Image

# %%
image = cv2.imread('interview-talk-bnk48-share.jpg')
(h, w, d) = image.shape
print(f'width={w}, height={h}, depth={d}')

# Use this code below when run Python code from command line
# cv2.imshow('Image', image)
# cv2.waitKey(0)

# In Jupyter notebook, we need to use Matplotlib to show an image
plt.figure(figsize=(10, 10))
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image);
# Out:
# width=1200, height=627, depth=3

# %% [markdown]
# ## Accessing Individual Pixel

# %%
(B, G, R) = image[100, 50]
print(f'R={R}, G={G}, B={B}')
# Out:
# R=102, G=104, B=103

# %% [markdown]
# ## Cropping Image

# %%
roi = image[25:310, 430:640]

plt.figure(figsize=(5, 5))
rgb_image = cv2.cvtColor(roi, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image);

# %% [markdown]
# ## Resizing Image

# %%
resized = cv2.resize(image, (300, 150))

plt.figure(figsize=(10, 10))
rgb_image = cv2.cvtColor(resized, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image);

# %%
import imutils

# %%
resized = imutils.resize(image, width=300)

plt.figure(figsize=(10, 10))
rgb_image = cv2.cvtColor(resized, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image);

# %% [markdown]
# ## Rotating Image

# %%
center = (w // 2, h // 2)
M = cv2.getRotationMatrix2D(center, -45, 1.0)
rotated = cv2.warpAffine(image, M, (w, h))

plt.figure(figsize=(10, 10))
rgb_image = cv2.cvtColor(rotated, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image);

# %%
rotated = imutils.rotate(image, -45)

plt.figure(figsize=(10, 10))
rgb_image = cv2.cvtColor(rotated, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image);

# %%
rotated = imutils.rotate_bound(image, 45)

plt.figure(figsize=(10, 10))
rgb_image = cv2.cvtColor(rotated, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image);

# %% [markdown]
# ## Drawing on Image

# %%
output = image.copy()
cv2.rectangle(output, (430, 25), (640, 310), (0, 0, 255), 5)

plt.figure(figsize=(10, 10))
rgb_image = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image);

# %%
output = image.copy()
cv2.putText(output, '<Hello World \>', (420, 340), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 255, 0), 3)

plt.figure(figsize=(10, 10))
rgb_image = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image);
